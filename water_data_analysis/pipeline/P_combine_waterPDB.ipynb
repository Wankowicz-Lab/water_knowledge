# %%
import os
import gemmi
import numpy as np

# %%
def read_csv(file):
    """
    Read a csv file and return a list of the lines.
    """
    with open(file, 'r') as file:
        lines=file.readlines()
    files=[line.strip() for line in lines]
    return files

# %%
def parse_pdb(filepath):
    with open(filepath, 'r') as file:
        lines = file.readlines()
    return [line for line in lines if line.startswith(('ATOM', 'HETATM', 'HEADER', 'COMPND', 'SOURCE', 'EXPDTA', 'REMARK', 'SEQRES', 'HET', 'HETNAM', 'FORMUL', 'LINK', 'CRYST1', 'ANISOU', ))]

# %%
def calculate_ave_b(pdb_path):
    """Calculate the averate B factor for all atoms of a given pdb file."""
    structure=gemmi.read_structure(pdb_path)

    # Generate dictionary of all atoms.
    chain_keys=['seq_id', 'res', 'b_fac', 'atom']
    structure = gemmi.read_structure(os.path.join(nowat_dir, '6ym8.pdb'))
    # Check model.
    i = 0
    model = structure[i]  # consider the first model (skip if empty)
    while len(model) == 0:  # sometimes the first model is empty
        i += 1
        try:
            model = structure[i]
        except Exception:
            raise ValueError("Can't read valid model from the input PDB file!")
    # Chain.
    # at_dict = {x.atom.name: x.atom.b_iso for x in model.all()} # CANNOT use atom name, otherwise will be updated.
    at_dict = {x.atom: x.atom.b_iso for x in model.all()} # CANNOT use atom name, otherwise will be updated.

    # Calculate the average B factor for all atoms.
    all_b = list(at_dict.values())
    average_b = round(np.average(all_b), 2)

    return average_b

# %%
def process_water_pdb_Average_B_HP(water_pdb_lines, average_b):
    """FOr HydraProt output, modify B factor of water lines by multiplying the average B factor of protein atoms and plus 50."""
    new_lines = []
    for atom_number, line in enumerate(water_pdb_lines):
        if line.startswith(('ATOM', 'HETATM')):
            new_residue_number = atom_number
            raw_b = line[62:67] # b factor.
            new_b = round((float(raw_b.strip()) * average_b + 50), 2) # Multiply by average B factor of protein then plus 50. Then round to 2 decimals.
            new_line = (
                f"{line[:21]}S{line[22:26].replace(line[22:26], f'{new_residue_number:4d}')}{line[26:60]}  {str(new_b)}{line[67:]}"
            )
            
            new_lines.append(new_line)
    return new_lines

# %%
def process_water_pdb_Average_B_SW(water_pdb_lines, average_b):
    """FOr SuperWater output, modify B factor of water lines by multiplying the average B factor of protein atoms by 1.5 since SW outputs zero B factors."""
    new_lines = []
    for atom_number, line in enumerate(water_pdb_lines):
        if line.startswith(('ATOM', 'HETATM')):
            new_residue_number = atom_number
            raw_b = line[62:67] # b factor.
            new_b = round((1.5 * average_b), 2) # Multiply the average B factor of protein by 1.5. Then round to 2 decimals.
            new_line = (
                f"{line[:21]}S{line[22:26].replace(line[22:26], f'{new_residue_number:4d}')}{line[26:60]}  {str(new_b)}{line[67:]}"
            )
            
            new_lines.append(new_line)
    return new_lines

# %%
def merge_pdb_files_B(nowat_pdb_path, water_pdb_path, output_pdb_path, average_b, model_type):
    """
    Generate combined PDB file with water lines modified with new B factors.
    Depending on the model_type (SuperWater/HydraProt), B factors are updated in different ways.
    model_type = 'SW' or 'HP'
    """
    nowat_pdb_lines = parse_pdb(nowat_pdb_path)
    water_pdb_lines = parse_pdb(water_pdb_path)

    # For different model output, B factors are updated in different ways.
    if model_type == 'SW':
        modified_water_lines = process_water_pdb_Average_B_SW(water_pdb_lines, average_b)
    elif model_type =='HP':
        modified_water_lines = process_water_pdb_Average_B_HP(water_pdb_lines, average_b)
    else:
        print('Need input of model type to correct B factors.')
    
    merged_lines = nowat_pdb_lines + ['TER\n'] + modified_water_lines + ['END\n'] 
    with open(output_pdb_path, 'w') as output_file:
        output_file.writelines(merged_lines)
    
    print(f"Merged PDB file saved as: {output_pdb_path}")

# %%
pwd
# Out:
# '/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline'

# %%
nowat_dir='/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat' # generated by grep (Ahmed's code)/ '{id}.pdb'
HP_dir='/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_HP' # "{id}_final_waters.pdb"
SW_dir='/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney' # "./{id}/{id}_centroid.pdb"

# %%
test_ids=read_csv('/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/test_split.txt')

# %%
# Generate output directory.
# os.mkdir('/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_HP_merged')
output_dir='/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_HP_merged'

# %%
# Generate output directory for correcting B factors.
# os.mkdir('/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_HP_merged_B')
output_dir_HP_B='/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_HP_merged_B'

# %%
# Generate output directory for correcting B factors.
# os.mkdir('/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B')
output_dir_SW_B='/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B'

# %%
for pdb in test_ids:
    if os.path.exists(os.path.join(nowat_dir, f"{pdb}.pdb")) and os.path.exists(os.path.join(HP_dir, f"{pdb}_final_waters.pdb")) and os.path.exists(os.path.join(SW_dir, pdb, f"{pdb}_centroid.pdb")):
        nowat_pdb_path = os.path.join(nowat_dir, f"{pdb}.pdb")
        superwater_pdb_path = os.path.join(SW_dir, pdb, f"{pdb}_centroid.pdb")
        hydraprot_pdb_path = os.path.join(HP_dir, f"{pdb}_final_waters.pdb")
        superwater_output_pdb_path = os.path.join(output_dir_SW_B, f"{pdb}_sw_merged.pdb")
        hydraprot_output_pdb_path = os.path.join(output_dir_HP_B, f"{pdb}_hp_merged.pdb")
        

        print(f"Merging {nowat_pdb_path} and {superwater_pdb_path} into {superwater_output_pdb_path}")
        average_b = calculate_ave_b(nowat_pdb_path)
        merge_pdb_files_B(nowat_pdb_path, superwater_pdb_path, superwater_output_pdb_path, average_b, model_type='SW')
        
        # print(f"Merging {nowat_pdb_path} and {hydraprot_pdb_path} into {hydraprot_output_pdb_path}")
        # average_b = calculate_ave_b(nowat_pdb_path)
        # merge_pdb_files_B(nowat_pdb_path, hydraprot_pdb_path, hydraprot_output_pdb_path, average_b, model_type='HP')
# Out:
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6ym8.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6ym8/6ym8_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6ym8_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6ym8_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pu7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pu7/5pu7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pu7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pu7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7su4.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7su4/7su4_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7su4_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7su4_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6k17.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6k17/6k17_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6k17_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6k17_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2ovy.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2ovy/2ovy_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2ovy_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2ovy_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pes.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pes/5pes_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pes_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pes_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4ngy.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4ngy/4ngy_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4ngy_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4ngy_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3nd1.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3nd1/3nd1_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3nd1_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3nd1_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7o3q.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7o3q/7o3q_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7o3q_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7o3q_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7rws.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7rws/7rws_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7rws_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7rws_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2yj7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2yj7/2yj7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2yj7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2yj7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2dga.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2dga/2dga_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2dga_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2dga_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3aau.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3aau/3aau_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3aau_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3aau_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6bsq.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6bsq/6bsq_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6bsq_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6bsq_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1j3f.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1j3f/1j3f_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1j3f_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1j3f_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3t01.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3t01/3t01_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3t01_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3t01_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pgj.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pgj/5pgj_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pgj_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pgj_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6yme.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6yme/6yme_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6yme_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6yme_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3me7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3me7/3me7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3me7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3me7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pe4.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pe4/5pe4_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pe4_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pe4_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3eo9.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3eo9/3eo9_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3eo9_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3eo9_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6zug.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6zug/6zug_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6zug_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6zug_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2vbl.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2vbl/2vbl_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2vbl_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2vbl_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5psu.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5psu/5psu_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5psu_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5psu_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3kmn.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3kmn/3kmn_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3kmn_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3kmn_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/9f5g.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/9f5g/9f5g_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/9f5g_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/9f5g_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2pnx.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2pnx/2pnx_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2pnx_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2pnx_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2h9b.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2h9b/2h9b_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2h9b_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2h9b_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3twy.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3twy/3twy_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3twy_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3twy_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5moc.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5moc/5moc_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5moc_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5moc_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1ijb.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1ijb/1ijb_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1ijb_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1ijb_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1kui.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1kui/1kui_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1kui_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1kui_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5ptr.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5ptr/5ptr_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5ptr_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5ptr_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3dmx.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3dmx/3dmx_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3dmx_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3dmx_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2x4w.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2x4w/2x4w_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2x4w_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2x4w_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6d45.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6d45/6d45_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6d45_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6d45_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6e0s.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6e0s/6e0s_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6e0s_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6e0s_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2yp9.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2yp9/2yp9_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2yp9_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2yp9_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3mlr.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3mlr/3mlr_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3mlr_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3mlr_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3h58.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3h58/3h58_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3h58_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3h58_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5jx4.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5jx4/5jx4_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5jx4_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5jx4_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2cf9.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2cf9/2cf9_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2cf9_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2cf9_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7nma.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7nma/7nma_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7nma_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7nma_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/8ar4.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/8ar4/8ar4_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/8ar4_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/8ar4_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2e2o.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2e2o/2e2o_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2e2o_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2e2o_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pt3.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pt3/5pt3_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pt3_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pt3_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4h2l.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4h2l/4h2l_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4h2l_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4h2l_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2owd.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2owd/2owd_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2owd_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2owd_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5iek.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5iek/5iek_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5iek_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5iek_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5i29.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5i29/5i29_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5i29_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5i29_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6je8.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6je8/6je8_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6je8_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6je8_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pdo.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pdo/5pdo_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pdo_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pdo_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3v1v.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3v1v/3v1v_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3v1v_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3v1v_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pb9.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pb9/5pb9_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pb9_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pb9_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3gwg.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3gwg/3gwg_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3gwg_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3gwg_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/8owo.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/8owo/8owo_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/8owo_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/8owo_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4e32.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4e32/4e32_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4e32_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4e32_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2qbw.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2qbw/2qbw_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2qbw_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2qbw_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4dh7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4dh7/4dh7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4dh7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4dh7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3dwz.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3dwz/3dwz_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3dwz_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3dwz_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6qwz.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6qwz/6qwz_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6qwz_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6qwz_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3vcl.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3vcl/3vcl_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3vcl_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3vcl_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3gc7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3gc7/3gc7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3gc7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3gc7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3soe.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3soe/3soe_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3soe_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3soe_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1i45.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1i45/1i45_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1i45_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1i45_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5n5t.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5n5t/5n5t_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5n5t_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5n5t_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7s27.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7s27/7s27_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7s27_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7s27_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7vqa.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7vqa/7vqa_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7vqa_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7vqa_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4hj7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4hj7/4hj7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4hj7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4hj7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1iju.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1iju/1iju_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1iju_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1iju_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4nmi.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4nmi/4nmi_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4nmi_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4nmi_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4hf7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4hf7/4hf7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4hf7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4hf7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4f6d.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4f6d/4f6d_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4f6d_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4f6d_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4uj7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4uj7/4uj7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4uj7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4uj7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7nzq.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7nzq/7nzq_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7nzq_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7nzq_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1zk1.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1zk1/1zk1_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1zk1_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1zk1_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1v9y.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1v9y/1v9y_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1v9y_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1v9y_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4czg.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4czg/4czg_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4czg_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4czg_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3cyz.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3cyz/3cyz_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3cyz_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3cyz_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1lu4.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1lu4/1lu4_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1lu4_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1lu4_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5meb.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5meb/5meb_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5meb_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5meb_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7o3r.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7o3r/7o3r_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7o3r_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7o3r_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2o5s.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2o5s/2o5s_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2o5s_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2o5s_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5vom.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5vom/5vom_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5vom_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5vom_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7fwv.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7fwv/7fwv_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7fwv_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7fwv_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pat.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pat/5pat_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pat_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pat_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3tgd.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3tgd/3tgd_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3tgd_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3tgd_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6cvw.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6cvw/6cvw_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6cvw_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6cvw_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3a7f.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3a7f/3a7f_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3a7f_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3a7f_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1y1f.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1y1f/1y1f_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1y1f_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1y1f_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5ebg.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5ebg/5ebg_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5ebg_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5ebg_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6zw2.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6zw2/6zw2_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6zw2_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6zw2_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3mn5.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3mn5/3mn5_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3mn5_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3mn5_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6ky3.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6ky3/6ky3_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6ky3_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6ky3_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7qxz.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7qxz/7qxz_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7qxz_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7qxz_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6zuh.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6zuh/6zuh_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6zuh_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6zuh_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2vpg.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2vpg/2vpg_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2vpg_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2vpg_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1h5h.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1h5h/1h5h_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1h5h_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1h5h_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6zs2.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6zs2/6zs2_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6zs2_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6zs2_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/8aof.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/8aof/8aof_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/8aof_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/8aof_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2vud.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2vud/2vud_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2vud_sw_merged.pdb
# ...
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7fw5_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4mwr.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4mwr/4mwr_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4mwr_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4mwr_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7gey.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7gey/7gey_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7gey_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7gey_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6ppa.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6ppa/6ppa_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6ppa_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6ppa_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pot.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pot/5pot_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pot_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pot_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5uxy.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5uxy/5uxy_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5uxy_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5uxy_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6diw.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6diw/6diw_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6diw_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6diw_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7ekz.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7ekz/7ekz_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7ekz_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7ekz_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2yaf.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2yaf/2yaf_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2yaf_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2yaf_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1l7f.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1l7f/1l7f_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1l7f_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1l7f_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4cp7.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4cp7/4cp7_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4cp7_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4cp7_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2r2c.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2r2c/2r2c_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2r2c_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2r2c_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6j9w.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6j9w/6j9w_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6j9w_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6j9w_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6x4q.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6x4q/6x4q_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6x4q_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6x4q_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3lil.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3lil/3lil_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3lil_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3lil_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/6yp3.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/6yp3/6yp3_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6yp3_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/6yp3_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7w5g.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7w5g/7w5g_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7w5g_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7w5g_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7obk.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7obk/7obk_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7obk_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7obk_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2w7h.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2w7h/2w7h_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2w7h_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2w7h_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1syh.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1syh/1syh_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1syh_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1syh_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7nyk.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7nyk/7nyk_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7nyk_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7nyk_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5qbv.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5qbv/5qbv_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5qbv_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5qbv_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3dm8.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3dm8/3dm8_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3dm8_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3dm8_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3ohg.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3ohg/3ohg_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3ohg_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3ohg_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5rjx.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5rjx/5rjx_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5rjx_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5rjx_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/3l5m.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/3l5m/3l5m_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3l5m_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/3l5m_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5ftq.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5ftq/5ftq_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5ftq_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5ftq_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4bw4.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4bw4/4bw4_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4bw4_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4bw4_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1wp5.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1wp5/1wp5_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1wp5_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1wp5_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/4jkh.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/4jkh/4jkh_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4jkh_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/4jkh_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/1nn5.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/1nn5/1nn5_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1nn5_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/1nn5_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/2rbu.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/2rbu/2rbu_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2rbu_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/2rbu_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/5pfe.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/5pfe/5pfe_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pfe_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/5pfe_sw_merged.pdb
# Merging /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/PDBs_test_SW_nowat/7d2m.pdb and /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/waterPDBs_test_SW_whitney/7d2m/7d2m_centroid.pdb into /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7d2m_sw_merged.pdb
# Merged PDB file saved as: /Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/output_SW_merged_B/7d2m_sw_merged.pdb
