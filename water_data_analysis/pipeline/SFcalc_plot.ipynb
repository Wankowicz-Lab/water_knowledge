# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pwd
# Out:
# '/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/notebook'

# %%
df_test=pd.read_csv("/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pipeline/Rfree_data_test.txt")

# %%
df_test
# Out:
#     name    r_free
# 0   1yd3  0.221482
# 1   1yld  0.241006
# 2   1yly  0.153423
# 3   1ylz  0.165858
# 4   1ylt  0.150086
# 5   1ylw  0.211668
# 6   1ylp  0.158466
# 7   1ylr  0.240432
# 8   1yd5  0.246848
# 9   1yd0  0.255603
# 10  1ylh  0.221150
# 11  1yd1  0.228279
# 12  1yd2  0.207932
# 13  1ylj  0.131636

# %%
df_test.r_free.hist()
plt.xlabel('R-free value')
# Out:
# Text(0.5, 0, 'R-free value')
