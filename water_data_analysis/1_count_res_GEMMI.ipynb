# %%
import os
import pathlib
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import gemmi

# %%
s_2yp9 = gemmi.read_structure("/Users/mingbin/Desktop/Wankowicz_lab_Mac/Projects/water/data/pdb_redo_data/2yp9_final.pdb")

# %%
s_2yp9
# Out:
# <gemmi.Structure 2yp9_final with 1 model(s)>

# %%
ent = s_2yp9.entities[0]

# %%
ent.subchains
# Out:
# ['Axp']

# %%
len(ent.full_sequence)
# Out:
# 503
